# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Verificando o CSV

# %%
df = pd.read_csv('./brazil_covid19_cities.csv')

# %% [markdown]
# # Verificando as Colunas

# %%
print(df.columns)
# Out:
# Index(['date', 'state', 'name', 'code', 'cases', 'deaths'], dtype='object')

# %%
df.plot(x='date', y=['cases', 'deaths'], figsize=(12, 6), 
        title='Avanço do novo coronavírus no Brasil', grid=True)

plt.show()
